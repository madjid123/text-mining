# %%
def init_youtube_api(i=2):
    import os

    # import google_auth_oauthlib.flow
    import googleapiclient.discovery
    import googleapiclient.errors
    scopes = ["https://www.googleapis.com/auth/youtube.readonly"]
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

    api_service_name = "youtube"
    api_version = "v3"
    client_secrets_file = "ytext.json"
    api_key=[
            "AIzaSyAcqEp_e8xM58dVyxdrlW13mufpfUaYbpw",
            "AIzaSyAZXsewT1lzwtVdMEIEpVibB6ZGRIWw7bo",
            "AIzaSyCbbDLlVaFWRSWCQEYFL-2g9SSvmo1GR9M"
            ]
    # Get credentials and create an API client
    # flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
    #     client_secrets_file, scopes)
    # credentials = flow.run_console()
    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, 
        # credentials=credentials)
        developerKey=api_key[2])
    return youtube

# %%
import json
def search_videos(query:str,statistics=True,save_json=False,publishedAfter="2022-11-20T01:00:00+01:00"):
    youtube = init_youtube_api()
    if len(query) ==0:
        return
    if save_json == True:
        f = open(f"{query}.json","r")
        allVideosRes = json.load(f.read(),ensure_ascii=False)
    allVideosRes = {}
    request = youtube.search().list(
        part="id",
        q=query,
        type="video"
        publishedAfter=publishedAfter
        )
    cpt = 0
    while request:
        respond = request.execute()
        allVideosRes += respond

        request = youtube.search().list_next(request, respond)

# %%
def get_video_comments(videoId,save_json=False,**kwargs):
    init_youtube_api() 
    if len(videoId) ==0:
        return
    if save_json == True:
        f = open(f"{query}.json","r")
        allVideosRes = json.load(f.read(),ensure_ascii=False)
    allVideosRes = {}
    request = youtube.commentThreads().list(
        **kwargs
    )
    respond = request.execute()
    return request,respond

    # request =

# %%
import os

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

scopes = ["https://www.googleapis.com/auth/youtube.readonly"]
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
client_secrets_file = "ytext.json"

# My First project , text-mining, My Project
api_key=["AIzaSyAcqEp_e8xM58dVyxdrlW13mufpfUaYbpw",
        "AIzaSyAZXsewT1lzwtVdMEIEpVibB6ZGRIWw7bo",
        "AIzaSyCbbDLlVaFWRSWCQEYFL-2g9SSvmo1GR9M"
        ]
# Get credentials and create an API client
# flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
#     client_secrets_file, scopes)
# credentials = flow.run_console()
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, 
    # credentials=credentials)
    developerKey=api_key[2])


request = youtube.search().list(
    part="id,snippet",
    # maxResults=100,
    q="FIFA World Cup Qatar 2022",
    type="video",
    publishedAfter="2022-11-20T01:00:00+01:00",
    fields = 'nextPageToken,items(id,snippet)',
    relevanceLanguage="en"


    )
vidswithComments ={}
# responseVid = request.execute()
prevRes={}
comm_len =0
cpt = 0
while request:
    response = request.execute()
    if cpt ==0:
        prevRes = response
    prevRes["items"] += response["items"]


    request = youtube.search().list_next(
        request, response)
    cpt+=1
for vid in prevRes["items"]:
    print(vid)
    # break
    vidId = vid["id"]["videoId"]
    vidTitle = vid["snippet"]["title"]
    vidReq = youtube.videos().list(
        part="statistics",
        id=vidId
    )
    vidRes = vidReq.execute()
    if "commentCount" not in vidRes["items"][0]["statistics"].keys():
        continue
    # print(vidRes) 
    # break
    commentReq = youtube.commentThreads().list(
        part="snippet",
        videoId =vidId
    )
    TotalCommentRes = {}
    cpt = 0
    while commentReq:
        response = commentReq.execute()
        if cpt ==0:
            TotalCommentRes= response
        TotalCommentRes["items"] += response["items"]


        commentReq = youtube.commentThreads().list_next(
            commentReq, response)
        cpt+=1
    comm_len += len(TotalCommentRes["items"])
    vidswithComments[vidId] = {"title":vidTitle,"comments":TotalCommentRes}

print(vidswithComments)
# for k,v in responseVid["items"]
# CommentReq = youtube.commentsThread().list(
#     videoId
# )
# print(responseVid["items"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 46
#      44 cpt = 0
#      45 while request:
# ---> 46     response = request.execute()
#      47     if cpt ==0:
#      48         prevRes = response
#
# File ~/Documents/uni_projects/text_mining_twitter/ytapi/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Documents/uni_projects/text_mining_twitter/ytapi/lib/python3.9/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# ...

# %%
for  i in prevRes["items"]:
    print(i['snippet']['title'])
# Out:
# Another famous comeback win | Japan v Spain | FIFA World Cup Qatar 2022
# 🔴 LIVE • ENGLAND vs. SENEGAL | World Cup Qatar 2022 • Round of 16 | RealisticSimulation
# FIFA 23 - BRAZIL vs SPAIN - FIFA World Cup Qatar 2022 Final - PC Gameplay - Full Match All Goals
# Alvarez makes his mark | Poland v Argentina | FIFA World Cup Qatar 2022
# Luis Chavez stunner not enough | Saudi Arabia v Mexico | FIFA World Cup Qatar 2022
# Another famous comeback win | Japan v Spain | FIFA World Cup Qatar 2022
# 🔴 LIVE • ENGLAND vs. SENEGAL | World Cup Qatar 2022 • Round of 16 | RealisticSimulation
# FIFA 23 - BRAZIL vs SPAIN - FIFA World Cup Qatar 2022 Final - PC Gameplay - Full Match All Goals
# Alvarez makes his mark | Poland v Argentina | FIFA World Cup Qatar 2022
# Luis Chavez stunner not enough | Saudi Arabia v Mexico | FIFA World Cup Qatar 2022
# FIFA WORLD CUP 2022 GROUP TABLES AND FINAL STANDINGS UPDATED | WORLD CUP 2022
# SUPER SUBS change game! | Spain v Germany | FIFA World Cup Qatar 2022
# ...

# %%
import json
vidsJson = json.dumps(vidswithComments,ensure_ascii=False)
f = open("WCvidsWithComments.json","w")
f.write(vidsJson)
f.close()

# %%
totalComm = 0
for k,v in vidswithComments.items():
    totalComm += len(v["comments"]["items"])
print(totalComm)
# Out:
# 1913
